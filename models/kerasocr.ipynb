# %% [markdown]
# https://www.analyticsvidhya.com/blog/2022/09/extract-text-from-images-quickly-using-keras-ocr-pipeline/

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\tonyf\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\tonyf\.keras-ocr\crnn_kurapan.h5

# %%
# Read images from folder path to image object
images = [
    keras_ocr.tools.read(img) for img in ['../test/test.jpg',
                                          '../session_12_Group_Work\Fuente0\parte_amistoso_0_1.jpg',]
]

# %%
# generate text predictions from the images
prediction_groups = pipeline.recognize(images)
# Out:
# 1/1 [==============================] - 27s 27s/step
# 19/19 [==============================] - 35s 2s/step

# %%
# plot the text predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, 
                                    predictions=predictions, 
                                    ax=ax)

# %%
predicted_image = prediction_groups[1]
for text, box in predicted_image:
    print(text)
# Out:
# declaracion
# amistosa
# de
# accidente
# del
# accidente
# localizacion
# victimalsl
# fecha
# hora
# 2
# lugar
# incluso
# levels
# eso
# 7
# be
# pais
# o
# 2
# e
# d
# no
# si
# danos
# materiales
# 5
# testigos
# nombre
# direccion
# tel
# vehiculos
# distintos
# de
# ay
# bjobjetos
# distintosal
# vehiculo
# u
# no
# si
# no
# si
# y
# 12
# circunstancias
# vehiculo
# a
#
# vehiculo
# b
# poner
# cada
# casilla
# aspa
# x
# en
# glasegurado
# un
# gasegurado
# poliza
# de
# vease
# poliza
# de
# vease
# segurol
# seguro
# proceda
# que
# para
# precisar
# el
# croquis
# a
# b
# nombret
# nombre
# s
# tachar
# as
# circunstacias
# validas
# no
# ssssan
# los
# g
# sco
# apellidos
# apellidos
# estaba
# estacionadolparado
# a
# cale
# cl
# s
# direccion
# direccion
# salia
# de
# estacionamientol
# un
# qulld
# abriendo
# le
# hdds
# puerta
# s
# codigo
# postalk
# paist
# codigo
# postalk
# pais
# estacionar
# o
# email
# iba
# tel
# email
# tel
# a
# lip
# o
# o
# s
# zlvehiculo
# salia
# de
# aparcamiento
# de
# zivehiculo
# un
# un
# s
# lugar
# privado
# de
# camino
# de
# tierra
# un
# s
# vehiculoa
# remolque
# remolque
# motor
# vehiculoa
# motor
# entrada
# aparcamiento
# a
# un
# a
# un
#
# marca
# modelo
# marca
# modelo
# privado
# camino
# de
# tierra
# lugar
# a
# un
# matricula
# bastidor
# matricula
# bastidor
# matricula
# lo
# bastidorj
# entrada
# sentido
# bastidorl
# lo
# o
# plaza
# de
# matricula
# lo
# a
# una
# se
# gs
# caas
# gratorio
# pais
# de
# matricula
# s
# pais
# matricula
# pais
# pais
# de
# de
# matricula
# de
# matricula
# circulaba
# plaza
# sentido
# por
# una
# de
# s
# giratorio
# 9
# 8
# aseguradora
# aseguradora
# s
# poliza
# de
# 8
# poliza
# de
# vease
# sequro
# ivease
# segurol
# 8
# colisiono
# g
# la
# parte
# de
# atras
# al
# otro
# en
# nombre
# brtoens
# nombre
# ogscn
# ea
# vehiculo
# circulaba
# el
# mismo
# que
# en
# t
# sentido
# y
# en
# el
# mismo
# carril
# s
# hide
# n
# o
# de
# no
# poliza
# de
# poliza
# ladhs
# g
# n
# de
# carta
# verdes
# no
# carta
# verdes
# o
# de
# 9
# circulaba
# mismo
# sentido
# en
# el
# y
# en
# s
# carril
# diferente
# certificadon
# certifcado
# s
# ichasta
# b
# verde
# hasta
# verde
# carta
# valida
# desde
# 10
# carta
# valida
# desde
# o
# 10
# cambiaba
# de
# carril
#
# loficina
# agencia
# loficina
# corredorl
# agencia
# corredorl
# o
# o
# adelantaba
# nombre
# nombre
# 12
# s
# giraba
# 12
# lunt
# la
# derecha
# toe
# a
# direccion
# direccion
# s
# 13
# 13
# pais
# giraba
# izquierda
# pais
# a
# la
# tel
# tel
# email
# og
# emailt
# o
# cals
# 88
# o
# 14
# daba
# marcha
# atras
# 8
# asegurados7
# asegurados
# ilos
# danos
# propios
# del
# vehiculo
# estan
# ilos
# danos
# propios
# del
# vehiculo
# estan
# s
# 15
# 15
# invadia
# la
# parte
# reservada
# la
# a
# sid
# no
# sil
# no
# circulacion
# sentido
# inverso
# en
# gconductor
# glconductor
# de
# conducird
# s
# iver
# permiso
# de
# conducir
# lver
# permiso
# 16
# venia
# de
# derecha
# 16
# la
# nombre
# nombre
# alellens
# len
# un
# crucel
# apellidos
# apellidos
# 17
# norespeto
# 17
# la
# senal
# de
# preferencia
# g
# ucalnol
# nacimientolizz
# fecha
# nacimiento
# fecha
# de
# semaforo
# rojo
# de
# o
# en
# direccion
# tae
# sl
# c
# direccions
# indicar
# de
# casillas
# numero
# marcadas
# pais
# pais
# deliden
# isgbe
# co
# aoet
# tel
# email
# firma
# de
# ambos
# obligatoria
# tel
# emailt
# o
# la
# conductores
# o
# es
# no
# impica
# reconocmiento
# derespansaoinoad
# pero
# una
# comect
# dus
# permiso
# de
# conducir
# permiso
# de
# conducir
# nod
# n
# oa
# s
# acilita
# la
# tramitacion
# consignacion
# dc
# tooos
# os
# catos
# accidente
# colisionj
# categoria
# a
# b
# 13
# croquis
# del
# len
# el
# de
# la
# 13
# categoria
# a
# b
# momento
# lal
# nd
# permiso
# valido
# hasta
# facia
# sitlacion
# dieccion
# lechas
# de
# los
# vshiclosh
# uposicionen
# permiso
# valido
# hastan
# aa
# fc
# matelo
# calge
# cogion
# senales
# ce
# vaico
# nototde
# escanes
# cueeas
# s
# 10
# indicar
# 10
# indicar
# el
# punto
# el
# punto
# de
# choque
# inicial
# de
# choque
# inicial
# la
# flecha
# con
# la
# flecha
# con
# danos
# danos
# 11
# apreciados
# 11
# apreciados
# vehiculo
# vehiculo
# b
# al
# a
# al
# s
# s
# e
# 14
# observaciones
# laobservaciones
# firma
# de
# los
# conductores
# 15
# 15
#
# a
# b
